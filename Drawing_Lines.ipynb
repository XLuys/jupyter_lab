# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_habits_performance_changed.csv')

# %%
x_line = np.linspace(df['study_hours_per_day'].min(), 6, 100)
y_line = (40*x_line)/3 + 20
y_linear_regression = 16.41 * x_line + 4.9
y_final_linear = 16.777870994333888 * x_line + 5.4375757585781885
y_another_linear = 11.427192940692729 * x_line + 27.93307455170724
y_scikit = 9.49025041 * x_line + 35.91016203402567

# %%
S = 10
ax = df.plot.scatter(x='study_hours_per_day', y='exam_score', title='Drawing Lines', grid=True, s=S, figsize=(10, 10))
ax.plot(x_line, y_line, color='green', label='Drawing Line')
ax.plot(x_line, y_linear_regression, color='#ff0000', label='Drawing Line')
ax.plot(x_line, y_another_linear, color='orange')
ax.plot(x_line, y_scikit, color='black', label='Drawing Line')

# %%
df_int.loc[
    df['mental_health_rating'] <= 4
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Mental Health Rating', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='red', s=S, label='Bad (<5)')
