# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import my_tools as tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
eps = 0.01
alpha = 0.1
steps = 1000

# %%
df = pd.read_csv('../student_habits_performance_changed.csv')
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='str')

# %%
df['extracurricular_participation'] = df['extracurricular_participation'].apply(lambda x: 1 if x == True else 0)

# %%
X = df[['study_hours_per_day', 'extracurricular_participation']].values
y = df['exam_score']

# %%
df1, df2 = tools.get_regression_stats(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1, df2 = tools.get_regression_stats(X, y)
#
# File ~/dev/python/machine_learning/jupyter_lab/LinearRegression/my_tools.py:92, in get_regression_stats(X, y)
#      89 B = np.matmul(np.matmul(X_inv, X_T), y)[:, None]
#      90 y_pred = np.sum(np.multiply(B, X_T), axis = 0)
# ---> 92 stats_df = pd.DataFrame()
#      93 meta_stats_df = pd.DataFrame()
#      95 names = ['RSE', 'R^2', 'Adj R^2', 'F-value']
#
# NameError: name 'pd' is not defined
