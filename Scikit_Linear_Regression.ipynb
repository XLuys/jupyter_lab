# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('student_habits_performance_changed.csv')

# %%
# df['exam_score'] -- df[]

# %%
reg = LinearRegression(copy_X=True).fit(df[['study_hours_per_day']], df['exam_score'])
reg.score(df[['study_hours_per_day']], df['exam_score'])
# Out:
# 0.6813157156535874

# %%
reg.coef_
# Out:
# array([9.49025041])

# %%
reg.intercept_
# Out:
# np.float64(35.91016203402567)
