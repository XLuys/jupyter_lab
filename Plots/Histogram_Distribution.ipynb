# %%
import pandas as pd
import numpy as np
import math
import kagglehub
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
df_int = pd.read_csv('student_habits_performance_changed.csv')

# %% [markdown]
# ## Scatter Plotting

# %% [markdown]
# ### Plots 1-6

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize = (20, 20))
axes = axes.flatten()
S = 15
df_int.plot.scatter(x='study_hours_per_day', y='exam_score', title='Normal Scatter Plot', ax=axes[0],
                   xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
                   color='dodgerblue', s=S)

### Plotting By Gender

df_int.loc[
    df_int['gender']=='Male'
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Gender', ax=axes[1],
              xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='dodgerblue', s=S, label='Male')
df_int.loc[
    df_int['gender']=='Female'
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Gender', ax=axes[1],
              xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='pink', s=S, label='Female')
df_int.loc[
    df_int['gender']=='Other'
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Gender', ax=axes[1],
              xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='purple', s=S, label='Other')

### Plotting By Mental Health Ratings
df_int.loc[
    df_int['mental_health_rating'] <= 4
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Mental Health Rating', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='red', s=S, label='Bad (<5)')
df_int.loc[
    df_int['mental_health_rating'].between(5, 8)
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Mental Health Rating', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='gold', s=S, label='Average (<9)')
df_int.loc[
    df_int['mental_health_rating'] > 8
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Mental Health Rating', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='lime', s=S, label='Good (>8)')

### Plotting By Internet Quality
df_int.loc[
    df_int['internet_quality'] == 0
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Internet Quality', 
              ax=axes[3], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='tomato', s=S, label='Bad')
df_int.loc[
    df_int['internet_quality'] == 1
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Internet Quality', 
              ax=axes[3], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='gold', s=S, label='Average')
df_int.loc[
    df_int['internet_quality'] == 2
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Internet Quality', 
              ax=axes[3], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='lightgreen', s=S, label='Good')

### Plotting By Sleep Hours
df_int.loc[
    df_int['sleep_hours'] < 6
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Sleep Hours', 
              ax=axes[4], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='red', s=S, label='Few (<6)')
df_int.loc[
    df_int['sleep_hours'].between(6, 7)
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Sleep Hours', 
              ax=axes[4], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='gold', s=S, label='Average (<7)')
df_int.loc[
    df_int['sleep_hours'] > 7
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Sleep Hours', 
              ax=axes[4], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='limegreen', s=S, label='Healthy (>7)')

### Plotting by Extracurricular Participation
df_int.loc[
    df_int['extracurricular_participation'] == False
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Extracurricular Participation', 
              ax=axes[5], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='lightsalmon', s=S, label='No')
df_int.loc[
    df_int['extracurricular_participation'] == True
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Plot By Extracurricular Participation', 
              ax=axes[5], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='limegreen', s=S, label='Yes')
# Out:
# <Axes: title={'center': 'Scatter Plot By Extracurricular Participation'}, xlabel='study_hours_per_day', ylabel='exam_score'>

# %% [markdown]
# ### Plots 7 - 10

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize = (20, 20))
axes = axes.flatten()
S = 15

### Plotting Exam_Score by Parental Education Level
df_int.loc[
    df_int['parental_education_level'] == 0
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Parental Education Level', 
              ax=axes[0], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='darkgrey', s=S, label='Highschool')
df_int.loc[
    df_int['parental_education_level'] == 1
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Parental Education Level', 
              ax=axes[0], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='deepskyblue', s=S, label='Bachelor')
df_int.loc[
    df_int['parental_education_level'] == 2
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Parental Education Level', 
              ax=axes[0], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='magenta', s=S, label='Master')
df_int.loc[
    df_int['parental_education_level'] == -1
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Parental Education Level', 
              ax=axes[0], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='black', s=S, label='Not Known')

### Plotting Exam_Score by Attendance Percentage
df_int.loc[
    df_int['attendance_percentage'] < 80.0 
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Attendance Percentage', 
              ax=axes[1], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='coral', s=S, label='Low')
df_int.loc[
    df_int['attendance_percentage'].between(80, 90)
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Attendance Percentage', 
              ax=axes[1], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='gold', s=S, label='Average')
df_int.loc[
    df_int['attendance_percentage'] > 90
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Scatter Attendance Percentage', 
              ax=axes[1], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='mediumspringgreen', s=S, label='High')

### Plotting Exam_Score by Exercise Frequency
df_int.loc[
    df_int['exercise_frequency'] < 2 
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Exercise Frequency', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='coral', s=S, label='Low')
df_int.loc[
    df_int['exercise_frequency'].between(2, 4)
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Exercise Frequency', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='gold', s=S, label='Average')
df_int.loc[
    df_int['exercise_frequency'] > 4
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Exercise Frequency', 
              ax=axes[2], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='mediumspringgreen', s=S, label='High')

### Plotting Exam_Score by Part Time Job
df_int.loc[
    df_int['part_time_job'] == True
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Exam Score by Part Time Job', 
              ax=axes[3], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='mediumspringgreen', s=S, label='Yes')
df_int.loc[
    df_int['part_time_job'] == False
].plot.scatter(x='study_hours_per_day', y='exam_score', title='Exam Score by Part Time Job', 
              ax=axes[3], xlabel='study_hours_per_day', ylabel='exam_score', grid=True,
              color='coral', s=S, label='No')

### Plotting Mental_Health_Rating By Social_Media_Hours
df_int.plot.scatter(x='social_media_hours', y='mental_health_rating',
              title='Mental Health Rating by Social Media Hours',
              ax=axes[4], grid = True, color='darkgray')
# Out:
# <Axes: title={'center': 'Mental Health Rating by Social Media Hours'}, xlabel='social_media_hours', ylabel='mental_health_rating'>

# %%
df_int['part_time_job'].value_counts()
# Out:
# part_time_job
# False    785
# True     215
# Name: count, dtype: int64

# %% [markdown]
# ## Histogram

# %%
plt.ioff()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize = (16, 20))
axes = axes.flatten()

# %%
mu, std = norm.fit(df_int['study_hours_per_day'])
df_int['study_hours_per_day'].plot(kind='hist', ax=axes[0], color='lightgreen', density=True,
                                   title='Histogram of study hours per day', edgecolor='black', xlabel='hours')
xmin, xmax = axes[0].get_xlim() # Corrected from `ax.get_xlim()`
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
axes[0].plot(x, p, 'darkgreen', linewidth=2, label=f'Normal Fit')
axes[0].set_xlabel('Hours')
axes[0].set_ylabel('Students')
axes[0].grid(axis='y', alpha=0.75)
axes[0].axvline(mu, color='darkgreen', linestyle='--', linewidth=2, label=f'Mean (μ={mu:.2f})')
axes[0].axvline(mu - std, color='darkgreen', linestyle=':', linewidth=2, label=f'σ ({std:.2f})')
axes[0].axvline(mu + std, color='darkgreen', linestyle=':', linewidth=2)
axes[0].axvline(mu - 2 * std, color='darkgreen', linestyle=':', linewidth=2)
axes[0].axvline(mu + 2 * std, color='darkgreen', linestyle=':', linewidth=2)
axes[0].legend()

mu, std = norm.fit(df_int['social_media_hours'])
df_int['social_media_hours'].plot(kind='hist', ax=axes[1], color='gray', density=True,
                                  title='Histogram of social media hours', edgecolor='black', xlabel='hours')
xmin, xmax = axes[1].get_xlim() # Corrected from `ax.get_xlim()`
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
axes[1].plot(x, p, 'k', linewidth=2, label=f'Normal Fit')
axes[1].set_xlabel('Hours')
axes[1].set_ylabel('Students')
axes[1].grid(axis='y', alpha=0.75)
axes[1].axvline(mu, color='k', linestyle='--', linewidth=2, label=f'Mean (μ={mu:.2f})')
axes[1].axvline(mu - std, color='k', linestyle=':', linewidth=2, label=f'σ ({std:.2f})')
axes[1].axvline(mu + std, color='k', linestyle=':', linewidth=2)
axes[1].axvline(mu + 2*std, color='k', linestyle=':', linewidth=2)
axes[1].axvline(mu - 2*std, color='k', linestyle=':', linewidth=2)
axes[1].legend()

# %%
mu, std = norm.fit(df_int['attendance_percentage'])
df_int['attendance_percentage'].plot(kind='hist', ax=axes[2], density=True,
                                     title='Histogram of attendance percentage', edgecolor='black', xlabel='percentage')
xmin, xmax = axes[2].get_xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
axes[2].plot(x, p, 'midnightblue', linewidth=2, label=f'Normal Fit')
axes[2].set_xlabel('Percentage')
axes[2].set_ylabel('Students')
axes[2].grid(axis='y', alpha=0.75)
axes[2].axvline(mu, color='midnightblue', linestyle='--', linewidth=2, label=f'Mean (μ={mu:.2f})')
axes[2].axvline(mu - std, color='midnightblue', linestyle=':', linewidth=2, label=f'σ ({std:.2f})')
axes[2].axvline(mu + std, color='midnightblue', linestyle=':', linewidth=2)
axes[2].axvline(mu + 2*std, color='midnightblue', linestyle=':', linewidth=2)
axes[2].axvline(mu - 2*std, color='midnightblue', linestyle=':', linewidth=2)
axes[2].legend()

mu, std = norm.fit(df_int['netflix_hours'])
df_int['netflix_hours'].plot(kind='hist', ax=axes[3], color='lightblue', density=True,
                             title='Histogram of netfilx hours', edgecolor='black', xlabel='hours')
xmin, xmax = axes[3].get_xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
axes[3].plot(x, p, 'cornflowerblue', linewidth=2, label=f'Normal Fit')
axes[3].set_xlabel('Hours')
axes[3].set_ylabel('Students')
axes[3].grid(axis='y', alpha=0.75)
axes[3].axvline(mu, color='cornflowerblue', linestyle='--', linewidth=2, label=f'Mean (μ={mu:.2f})')
axes[3].axvline(mu - std, color='cornflowerblue', linestyle=':', linewidth=2, label=f'σ ({std:.2f})')
axes[3].axvline(mu + std, color='cornflowerblue', linestyle=':', linewidth=2)
axes[3].axvline(mu + 2*std, color='cornflowerblue', linestyle=':', linewidth=2)
axes[3].axvline(mu - 2*std, color='cornflowerblue', linestyle=':', linewidth=2)
axes[3].legend()

# %%
mu, std = norm.fit(df_int['sleep_hours'])
df_int['sleep_hours'].plot(kind='hist', ax=axes[4], color='purple', density=True,
                           title='Histogram of sleep hours', edgecolor='black', xlabel='hours')
xmin, xmax = axes[4].get_xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
axes[4].plot(x, p, 'indigo', linewidth=2, label=f'Normal Fit')
axes[4].set_xlabel('Hours')
axes[4].set_ylabel('Students')
axes[4].grid(axis='y', alpha=0.75)
axes[4].axvline(mu, color='indigo', linestyle='--', linewidth=2, label=f'Mean (μ={mu:.2f})')
axes[4].axvline(mu - std, color='indigo', linestyle=':', linewidth=2, label=f'σ ({std:.2f})')
axes[4].axvline(mu + std, color='indigo', linestyle=':', linewidth=2)
axes[4].axvline(mu + 2*std, color='indigo', linestyle=':', linewidth=2)
axes[4].axvline(mu - 2*std, color='indigo', linestyle=':', linewidth=2)
axes[4].legend()

mu, std = norm.fit(df_int['exam_score'])
df_int['exam_score'].plot(kind='hist', ax=axes[5], color='lightyellow', density=True,
                          title='Histogram of exam score', edgecolor='black', xlabel='score')
xmin, xmax = axes[5].get_xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
axes[5].plot(x, p, 'darkkhaki', linewidth=2, label=f'Normal Fit')
axes[5].set_xlabel('Hours')
axes[5].set_ylabel('Students')
axes[5].grid(axis='y', alpha=0.75)
axes[5].axvline(mu, color='darkkhaki', linestyle='--', linewidth=2, label=f'Mean (μ={mu:.2f})')
axes[5].axvline(mu - std, color='darkkhaki', linestyle=':', linewidth=2, label=f'σ ({std:.2f})')
axes[5].axvline(mu + std, color='darkkhaki', linestyle=':', linewidth=2)
axes[5].axvline(mu + 2*std, color='darkkhaki', linestyle=':', linewidth=2)
axes[5].axvline(mu - 2*std, color='darkkhaki', linestyle=':', linewidth=2)
axes[5].legend()

# %%
fig

# %%
df_int['exam_score'].median()
# Out:
# np.float64(70.5)

# %%
df_int['exam_score'].mean()
# Out:
# np.float64(69.6015)

# %%
df_int['attendance_percentage'].describe()
# Out:
# count    1000.000000
# mean       84.131700
# std         9.399246
# min        56.000000
# 25%        78.000000
# 50%        84.400000
# 75%        91.025000
# max       100.000000
# Name: attendance_percentage, dtype: float64
